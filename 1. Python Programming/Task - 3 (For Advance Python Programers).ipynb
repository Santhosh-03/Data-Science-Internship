# %% [markdown]
# ## 1. Maximum Product of Two Elements in an Array
#
# Given the array of integers nums, you will choose two different indices i and j of that array. Return the maximum value of `(nums[i]-1)*(nums[j]-1)`.
#
# __Example 1:__
#
# __Input:__ `nums = [3,4,5,2]`
# __Output: 12__
#
# __Explanation:__ If you choose the indices i=1 and j=2 (indexed from 0), you will get the maximum value, that is, `(nums[1]-1)*(nums[2]-1) = (4-1)*(5-1) = 3*4 = 12`.
#
# __Example 2:__
#
# __Input:__ `nums = [1,5,4,5]`
# __Output: 16__
#
# __Explanation:__ Choosing the indices i=1 and j=3 (indexed from 0), you will get the maximum value of `(5-1)*(5-1) = 16`.
#
# __Example 3:__
#
# __Input:__ `nums = [3,7]`
# __Output:__ `12`
#
#
# __Constraints:__
#
# * 2 <= nums.length <= 500
# * 1 <= nums[i] <= 10^3

# %%
def maxProduct(nums):
    max_val = [] # empty list
    for i in range(len(nums)): # iterating the input list n times
        for j in range(i+1, len(nums)): # iterating the input list n times from the next element of i
            max_val.append((nums[i]-1) * (nums[j]-1))  # appending the value of (nums[i]-1) * (nums[j]-1)
    return max(max_val) # returning the maximum element from the list

# test case 1
nums = [3,4,5,2] # input list
print(maxProduct(nums)) # calling the function

# test case 2
nums = [1,5,4,5] # input list
print(maxProduct(nums)) # calling the function

# test case 3
nums = [3,7] # input list
print(maxProduct(nums)) # calling the function
# Out:
# 12
# 16
# 12

# %% [markdown]
# ## 2. Count Number of Teams
#
# There are n soldiers standing in a line. Each soldier is assigned a unique rating value.
#
# You have to form a team of 3 soldiers amongst them under the following rules:
#
# Choose 3 soldiers with index (i, j, k) with rating `(rating[i], rating[j], rating[k])`.
# A team is valid if: `(rating[i] < rating[j] < rating[k]) or (rating[i] > rating[j] > rating[k]) where (0 <= i < j < k < n)`.
# Return the number of teams you can form given the conditions. (soldiers can be part of multiple teams).
#
# __Example 1:__
#
# __Input:__ `rating = [2,5,3,4,1]`
# __Output:__ `3`
#
# __Explanation:__ We can form three teams given the conditions. `(2,3,4), (5,4,1), (5,3,1)`.
#
# __Example 2:__
#
# __Input:__ `rating = [2,1,3]`
# __Output:__ `0`
#
# __Explanation:__ We can't form any team given the conditions.
#
# __Example 3:__
#
# __Input:__ `rating = [1,2,3,4]`
# __Output:__ `4`
#
#
# __Constraints:__
#
# * n == rating.length
# * 3 <= n <= 1000
# * 1 <= rating[i] <= 105
# * All the integers in rating are unique.

# %%
def numTeams(rating):
    result = 0
    for idx, middle in enumerate(rating): # outer-loop is always going to be the middle element
        a = sum(left < middle for jdx, left in enumerate(rating[:idx])) # a searches left of the middle
        b = sum(left > middle for jdx, left in enumerate(rating[:idx])) # b searches left of the middle          
        c = sum(right < middle for jdx, right in enumerate(rating[idx+1:])) # c searches the right of the middle.
        d = sum(middle < right for jdx, right in enumerate(rating[idx+1:])) # d searches the right of the middle.
        result += a*d + b*c

    return result

# test case 1
rating = [2,5,3,4,1]
print(numTeams(rating)) # calling the function

# test case 2
rating = [2,1,3]
print(numTeams(rating)) # calling the function

# test case 3
rating = [1,2,3,4]
print(numTeams(rating)) # calling the function
# Out:
# 3
# 0
# 4

# %% [markdown]
# ## 3. Number of Students Doing Homework at a Given Time
#
# Given two integer arrays startTime and endTime and given an integer queryTime.
#
# The ith student started doing their homework at the time startTime[i] and finished it at time endTime[i].
#
# Return the number of students doing their homework at time queryTime. More formally, return the number of students where queryTime lays in the interval [startTime[i], endTime[i]] inclusive.
#
# __Example 1:__
#
# __Input:__ `startTime = [1,2,3]`, `endTime = [3,2,7]`, `queryTime = 4`
# __Output:__ `1`
#
# __Explanation:__ We have 3 students where:
# * The first student started doing homework at time 1 and finished at time 3 and wasn't doing anything at time 4.
# * The second student started doing homework at time 2 and finished at time 2 and also wasn't doing anything at time 4.
# * The third student started doing homework at time 3 and finished at time 7 and was the only student doing homework at time 4.
#
# __Example 2:__
#
# __Input:__ `startTime = [4]`, `endTime = [4]`, `queryTime = 4`
# __Output:__ `1`
#
# __Explanation:__ The only student was doing their homework at the queryTime.
#
# __Example 3:__
#
# __Input:__ `startTime = [4]`, `endTime = [4]`, `queryTime = 5`
# __Output:__ `0`
#
# __Example 4:__
#
# __Input:__ `startTime = [1,1,1,1]`, `endTime = [1,3,2,4]`, `queryTime = 7`
# __Output:__ `0`
#
# __Example 5:__
#
# __Input:__ `startTime = [9,8,7,6,5,4,3,2,1]`, `endTime = [10,10,10,10,10,10,10,10,10]`, `queryTime = 5`
# __Output:__ `5`
#
# __Constraints:__
#
# * startTime.length == endTime.length
# * 1 <= startTime.length <= 100
# * 1 <= startTime[i] <= endTime[i] <= 1000
# * 1 <= queryTime <= 1000

# %%
def busyStudent(startTime, endTime, queryTime):
    count = 0 # creating a counter variable
    for idx in range(len(startTime)): # running iteration n times
        # checking if startTime is lesser than queryTime and queryTime is less than endTime of position idx
        if(startTime[idx] <= queryTime) and (queryTime <= endTime[idx]):
            count += 1 # increamenting the count
    return count


# test case 1
startTime = [1,2,3]
endTime = [3,2,7]
queryTime = 4
print(busyStudent(startTime, endTime, queryTime)) # calling the function

# test case 2
startTime = [4]
endTime = [4]
queryTime = 4
print(busyStudent(startTime, endTime, queryTime)) # calling the function

# test case 3
startTime = [4]
endTime = [4]
queryTime = 5
print(busyStudent(startTime, endTime, queryTime)) # calling the function

# test case 4
startTime = [1,1,1,1]
endTime = [1,3,2,4]
queryTime = 7
print(busyStudent(startTime, endTime, queryTime)) # calling the function

# test case 5
startTime = [9,8,7,6,5,4,3,2,1]
endTime = [10,10,10,10,10,10,10,10,10]
queryTime = 5
print(busyStudent(startTime, endTime, queryTime)) # calling the function
# Out:
# 1
# 1
# 0
# 0
# 5
# 1

# %% [markdown]
# ## 4. Number of Steps to Reduce a Number to Zero
#
# Given an integer num, return the number of steps to reduce it to zero.
#
# In one step, if the current number is even, you have to divide it by 2, otherwise, you have to subtract 1 from it.
#
# __Example 1:__
#
# __Input:__ `num = 14`
# __Output: 6__
#
# __Explanation:__
# * Step 1) 14 is even; divide by 2 and obtain 7.
# * Step 2) 7 is odd; subtract 1 and obtain 6.
# * Step 3) 6 is even; divide by 2 and obtain 3.
# * Step 4) 3 is odd; subtract 1 and obtain 2.
# * Step 5) 2 is even; divide by 2 and obtain 1.
# * Step 6) 1 is odd; subtract 1 and obtain 0.
#
# __Example 2:__
#
# __Input:__ `num = 8`
# __Output: 4__
#
# __Explanation:__
#
# * Step 1) 8 is even; divide by 2 and obtain 4.
# * Step 2) 4 is even; divide by 2 and obtain 2.
# * Step 3) 2 is even; divide by 2 and obtain 1.
# * Step 4) 1 is odd; subtract 1 and obtain 0.
#
# __Example 3:__
#
# __Input:__ `num = 123`
# __Output:__ `12`
#
# __Constraints:__
#
# * 0 <= num <= 106

# %%
def numberOfSteps(num):
    steps = 0 # creating a counter variable
    while(num != 0): # checking whether num is 0
        if num%2 == 0: # checking whether num is even
            num = num // 2 # doing integer division
            steps += 1 # increamenting the step
        else: # num is odd
            num = num - 1 # decreamenting num
            steps += 1 # increamenting the step

    return steps

# test case 1
num = 14
print(numberOfSteps(num)) # calling the function

# test case 2
num = 8
print(numberOfSteps(num)) # calling the function

# test case 3
num = 123
print(numberOfSteps(num)) # calling the function
# Out:
# 6
# 4
# 12

# %% [markdown]
# ## 5. Counting Bits
# Given an integer n, return an array ans of length n + 1 such that for each i (0 <= i <= n), ans[i] is the number of 1's in the binary representation of i.
#
# __Example 1:__
#
# __Input:__ `n = 2`
# __Output:__ `[0,1,1]`
#
# __Explanation:__
# * 0 --> 0
# * 1 --> 1
# * 2 --> 10
#
# __Example 2:__
#
# __Input:__ `n = 5`
# __Output:__ `[0,1,1,2,1,2]`
#
# __Explanation:__
# * 0 --> 0
# * 1 --> 1
# * 2 --> 10
# * 3 --> 11
# * 4 --> 100
# * 5 --> 101
#
# __Constraints:__
#
# * 0 <= n <= 105

# %%
def countBits(n):
    ones_count = [] # emoty list
    for num in range(n+1): # iterating n+1 times
        binary_num = bin(num) # finding the binary representation of num
        ones_count.append(binary_num.count('1')) # finding the count of 1 in binary format of num
    return ones_count

# test case 1
n = 2
print(countBits(n)) # calling the function

# test case 2
n = 5
print(countBits(n)) # calling the function
# Out:
# [0, 1, 1]
# [0, 1, 1, 2, 1, 2]
